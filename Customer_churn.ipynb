# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets/Customer_Churn.csv")
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis='columns',inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-06ba430a4ba5> in <cell line: 1>()
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df1=df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
pd.to_numeric(df1.TotalCharges)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
tenure_churn_no=df1[df1.Churn=='No'].tenure
tenure_churn_yes=df1[df1.Churn=='Yes'].tenure

plt.xlabel('tenure')
plt.ylabel('Number of customers')
plt.title("Customer Churn Prediction Visualization")

plt.hist([tenure_churn_yes,tenure_churn_no],color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_col_value(df):
  for column in df:
    if df[column].dtypes=='object':
       print(f'{column} : {df[column].unique()}')

# %%
print_unique_col_value(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_value(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
yes_no_columns=['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
               'DeviceProtection','PaperlessBilling','TechSupport','StreamingTV','StreamingMovies','PaymentMethod','Churn']

for col in yes_no_columns:
  df1[col].replace({'Yes':1,'No':0},inplace=True)
# Out:
# <ipython-input-41-33b04d6c3053>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1,'No':0},inplace=True)

# %%
for col in df1:
       print(f'{col} : {df1[col].unique()}')
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : [1 0]
# Dependents : [0 1]
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService : [0 1]
# MultipleLines : [0 1]
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : [0 1]
# OnlineBackup : [1 0]
# DeviceProtection : [0 1]
# TechSupport : [0 1]
# StreamingTV : [0 1]
# StreamingMovies : [0 1]
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : [1 0]
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges : [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges : [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn : [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# <ipython-input-44-ba153b6b6960>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0])

# %%
#one-hot encoding
df2=pd.get_dummies(data=df1,columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1383       1              0        0           0       1             1
# 2176       0              0        1           1      67             1
# 270        1              1        0           0      16             1
# 4910       1              0        0           0      30             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 1383              1               0             0                 0  ...
# 2176              0               0             0                 0  ...
# 270               0               0             0                 0  ...
# 4910              0               1             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 1383                    1                            0                   0
# 2176                    0                            0                   1
# 270                     0                            1                   0
# 4910                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 1383                        1                  0                  0
# 2176                        0                  0                  1
# 270                         1                  0                  0
# 4910                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 1383                                        1
# 2176                                        0
# 270                                         0
# 4910                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 1383                                      0                               0
# 2176                                      1                               0
# 270                                       0                               1
# 4910                                      0                               0
#
#       PaymentMethod_Mailed check
# 1383                           0
# 2176                           0
# 270                            0
# 4910                           0
#
# [4 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale=['tenure','MonthlyCharges','TotalCharges']
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
df2[cols_to_scale]=scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 6443       1              0        0           0  0.112676             1
# 4602       1              0        0           0  0.929577             1
# 6956       0              1        0           0  0.929577             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 6443              0               0             0                 0  ...
# 4602              1               0             0                 0  ...
# 6956              1               1             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 6443                    0                            0                   1
# 4602                    0                            0                   1
# 6956                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 6443                        1                  0                  0
# 4602                        0                  0                  1
# 6956                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 6443                                        1
# 4602                                        0
# 6956                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6443                                      0                               0
# 4602                                      0                               0
# 6956                                      0                               0
#
#       PaymentMethod_Mailed check
# 6443                           0
# 4602                           1
# 6956                           0
#
# [3 rows x 27 columns]

# %%
X=df2.drop('Churn',axis='columns')
y=df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=5)

# %%
import tensorflow as tf
from tensorflow import keras

model=keras.Sequential([
    keras.layers.Dense(20,input_shape=(26,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid'),

])
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 4ms/step - loss: 0.5917 - accuracy: 0.6676
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7920
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4242 - accuracy: 0.8005
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4174 - accuracy: 0.8032
# Epoch 5/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4148 - accuracy: 0.8057
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4130 - accuracy: 0.8050
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4120 - accuracy: 0.8071
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4114 - accuracy: 0.8069
# Epoch 9/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8073
# Epoch 10/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8073
# Epoch 11/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4091 - accuracy: 0.8080
# Epoch 12/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4080 - accuracy: 0.8089
# Epoch 13/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4077 - accuracy: 0.8103
# Epoch 14/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4062 - accuracy: 0.8130
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8103
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8123
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8117
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4048 - accuracy: 0.8132
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8112
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8130
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8135
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8112
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8140
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8140
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8142
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4009 - accuracy: 0.8133
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4005 - accuracy: 0.8140
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8132
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8155
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8151
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8155
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8140
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8149
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.8149
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8187
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8149
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8137
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8126
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8160
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8151
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8153
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8164
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8158
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8155
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8197
# Epoch 46/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3940 - accuracy: 0.8180
# Epoch 47/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3936 - accuracy: 0.8171
# Epoch 48/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8183
# Epoch 49/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3932 - accuracy: 0.8176
# Epoch 50/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8178
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3922 - accuracy: 0.8178
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8187
# Epoch 53/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3917 - accuracy: 0.8172
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8178
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8162
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8172
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8178
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8164
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8199
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8197
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8210
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8181
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8192
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8210
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8203
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8213
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8217
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8185
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8196
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.8199
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8197
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8217
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3870 - accuracy: 0.8203
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8204
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8190
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.8222
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8224
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8217
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8204
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8217
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8244
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8206
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.8219
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8249
# Epoch 85/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3848 - accuracy: 0.8231
# Epoch 86/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3839 - accuracy: 0.8222
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8203
# Epoch 88/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8240
# Epoch 89/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3834 - accuracy: 0.8240
# Epoch 90/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8242
# Epoch 91/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.8249
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3823 - accuracy: 0.8245
# Epoch 93/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3823 - accuracy: 0.8256
# Epoch 94/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3823 - accuracy: 0.8213
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8229
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8210
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8256
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3819 - accuracy: 0.8254
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8245
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8233

# %%
model.evaluate(X_test,y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7910
# [0.44967418909072876, 0.7910447716712952]

# %%
yp=model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[0.18962061],
#        [0.4214949 ],
#        [0.01602164],
#        [0.81315506],
#        [0.59789306]], dtype=float32)

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
y_pred=[]
for element in yp:
  if element > 0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 0, 0, 1, 1, 1, 0, 1, 0, 0]

# %%
from sklearn.metrics import confusion_matrix,classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86       999
#            1       0.66      0.57      0.61       408
#
#     accuracy                           0.79      1407
#    macro avg       0.75      0.73      0.73      1407
# weighted avg       0.78      0.79      0.79      1407

# %%
import seaborn as sns
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_pred)
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(95.72222222222221, 0.5, 'Actual')
